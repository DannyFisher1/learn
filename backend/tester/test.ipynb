# %%
from langchain_core.messages import AIMessage, HumanMessage
from langchain_google_vertexai.vision_models import VertexAIImageGeneratorChat
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 from langchain_core.messages import AIMessage, HumanMessage
# ----> 2 from langchain_google_vertexai.vision_models import VertexAIImageGeneratorChat
#
# ModuleNotFoundError: No module named 'langchain_google_vertexai'
